# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 912us/sample - loss: 260.3442 - y1_output_loss: 120.9311 - y2_output_loss: 137.6180 - y1_output_root_mean_squared_error: 11.0312 - y2_output_root_mean_squared_error: 11.7752 - val_loss: 71.2479 - val_y1_output_loss: 30.2435 - val_y2_output_loss: 39.8468 - val_y1_output_root_mean_squared_error: 5.5163 - val_y2_output_root_mean_squared_error: 6.3889
# Epoch 2/500
# 614/614 [==============================] - 0s 140us/sample - loss: 29.2098 - y1_output_loss: 11.9023 - y2_output_loss: 17.2774 - y1_output_root_mean_squared_error: 3.4564 - y2_output_root_mean_squared_error: 4.1549 - val_loss: 44.5401 - val_y1_output_loss: 12.4520 - val_y2_output_loss: 30.9417 - val_y1_output_root_mean_squared_error: 3.5637 - val_y2_output_root_mean_squared_error: 5.6427
# Epoch 3/500
# 614/614 [==============================] - 0s 137us/sample - loss: 24.7432 - y1_output_loss: 9.7836 - y2_output_loss: 14.7986 - y1_output_root_mean_squared_error: 3.1337 - y2_output_root_mean_squared_error: 3.8631 - val_loss: 20.2809 - val_y1_output_loss: 8.0067 - val_y2_output_loss: 11.6637 - val_y1_output_root_mean_squared_error: 2.8717 - val_y2_output_root_mean_squared_error: 3.4690
# Epoch 4/500
# 614/614 [==============================] - 0s 134us/sample - loss: 24.3902 - y1_output_loss: 9.6300 - y2_output_loss: 14.8354 - y1_output_root_mean_squared_error: 3.1108 - y2_output_root_mean_squared_error: 3.8358 - val_loss: 30.6867 - val_y1_output_loss: 10.0768 - val_y2_output_loss: 20.1614 - val_y1_output_root_mean_squared_error: 3.2271 - val_y2_output_root_mean_squared_error: 4.5025
# Epoch 5/500
# 614/614 [==============================] - 0s 130us/sample - loss: 26.3473 - y1_output_loss: 9.7930 - y2_output_loss: 16.7654 - y1_output_root_mean_squared_error: 3.1222 - y2_output_root_mean_squared_error: 4.0742 - val_loss: 25.3246 - val_y1_output_loss: 7.3490 - val_y2_output_loss: 17.6471 - val_y1_output_root_mean_squared_error: 2.7484 - val_y2_output_root_mean_squared_error: 4.2155
# Epoch 6/500
# 614/614 [==============================] - 0s 138us/sample - loss: 26.4562 - y1_output_loss: 9.6564 - y2_output_loss: 16.9583 - y1_output_root_mean_squared_error: 3.1120 - y2_output_root_mean_squared_error: 4.0953 - val_loss: 47.7811 - val_y1_output_loss: 11.4549 - val_y2_output_loss: 35.0927 - val_y1_output_root_mean_squared_error: 3.4287 - val_y2_output_root_mean_squared_error: 6.0021
# Epoch 7/500
# 614/614 [==============================] - 0s 131us/sample - loss: 24.1285 - y1_output_loss: 9.2435 - y2_output_loss: 14.7760 - y1_output_root_mean_squared_error: 3.0361 - y2_output_root_mean_squared_error: 3.8614 - val_loss: 32.1422 - val_y1_output_loss: 13.8762 - val_y2_output_loss: 17.9983 - val_y1_output_root_mean_squared_error: 3.7652 - val_y2_output_root_mean_squared_error: 4.2386
# Epoch 8/500
# 614/614 [==============================] - 0s 127us/sample - loss: 21.1006 - y1_output_loss: 8.9576 - y2_output_loss: 12.1938 - y1_output_root_mean_squared_error: 2.9870 - y2_output_root_mean_squared_error: 3.4898 - val_loss: 32.7463 - val_y1_output_loss: 9.4901 - val_y2_output_loss: 22.4030 - val_y1_output_root_mean_squared_error: 3.1119 - val_y2_output_root_mean_squared_error: 4.8023
# Epoch 9/500
# 614/614 [==============================] - 0s 127us/sample - loss: 19.8291 - y1_output_loss: 8.2518 - y2_output_loss: 11.4640 - y1_output_root_mean_squared_error: 2.8855 - y2_output_root_mean_squared_error: 3.3916 - val_loss: 17.2536 - val_y1_output_loss: 6.8886 - val_y2_output_loss: 9.9111 - val_y1_output_root_mean_squared_error: 2.6680 - val_y2_output_root_mean_squared_error: 3.1836
# Epoch 10/500
# 614/614 [==============================] - 0s 141us/sample - loss: 20.0637 - y1_output_loss: 8.0623 - y2_output_loss: 11.9489 - y1_output_root_mean_squared_error: 2.8438 - y2_output_root_mean_squared_error: 3.4607 - val_loss: 19.8391 - val_y1_output_loss: 8.2219 - val_y2_output_loss: 10.9904 - val_y1_output_root_mean_squared_error: 2.9194 - val_y2_output_root_mean_squared_error: 3.3639
# Epoch 11/500
# 614/614 [==============================] - 0s 132us/sample - loss: 21.0869 - y1_output_loss: 8.3253 - y2_output_loss: 12.7018 - y1_output_root_mean_squared_error: 2.8789 - y2_output_root_mean_squared_error: 3.5775 - val_loss: 20.1102 - val_y1_output_loss: 8.8627 - val_y2_output_loss: 10.6234 - val_y1_output_root_mean_squared_error: 3.0281 - val_y2_output_root_mean_squared_error: 3.3077
# Epoch 12/500
# 614/614 [==============================] - 0s 135us/sample - loss: 23.5442 - y1_output_loss: 9.2146 - y2_output_loss: 14.8876 - y1_output_root_mean_squared_error: 2.9934 - y2_output_root_mean_squared_error: 3.8189 - val_loss: 48.7582 - val_y1_output_loss: 14.9833 - val_y2_output_loss: 34.0383 - val_y1_output_root_mean_squared_error: 3.8943 - val_y2_output_root_mean_squared_error: 5.7959
# Epoch 13/500
# 614/614 [==============================] - 0s 136us/sample - loss: 21.9707 - y1_output_loss: 8.3096 - y2_output_loss: 14.3695 - y1_output_root_mean_squared_error: 2.8497 - y2_output_root_mean_squared_error: 3.7215 - val_loss: 61.1714 - val_y1_output_loss: 12.6239 - val_y2_output_loss: 48.0069 - val_y1_output_root_mean_squared_error: 3.5292 - val_y2_output_root_mean_squared_error: 6.9797
# Epoch 14/500
# 614/614 [==============================] - 0s 135us/sample - loss: 21.6144 - y1_output_loss: 8.3274 - y2_output_loss: 13.2380 - y1_output_root_mean_squared_error: 2.8933 - y2_output_root_mean_squared_error: 3.6391 - val_loss: 38.5723 - val_y1_output_loss: 10.1984 - val_y2_output_loss: 27.4816 - val_y1_output_root_mean_squared_error: 3.2141 - val_y2_output_root_mean_squared_error: 5.3143
# Epoch 15/500
# 614/614 [==============================] - 0s 130us/sample - loss: 20.3806 - y1_output_loss: 7.8204 - y2_output_loss: 12.6130 - y1_output_root_mean_squared_error: 2.7966 - y2_output_root_mean_squared_error: 3.5440 - val_loss: 24.2785 - val_y1_output_loss: 8.1437 - val_y2_output_loss: 15.6286 - val_y1_output_root_mean_squared_error: 2.9059 - val_y2_output_root_mean_squared_error: 3.9793
# Epoch 16/500
# 614/614 [==============================] - 0s 136us/sample - loss: 19.2875 - y1_output_loss: 7.6272 - y2_output_loss: 11.7389 - y1_output_root_mean_squared_error: 2.7335 - y2_output_root_mean_squared_error: 3.4374 - val_loss: 18.2047 - val_y1_output_loss: 7.3377 - val_y2_output_loss: 10.2712 - val_y1_output_root_mean_squared_error: 2.7491 - val_y2_output_root_mean_squared_error: 3.2630
# Epoch 17/500
# 614/614 [==============================] - 0s 133us/sample - loss: 16.5858 - y1_output_loss: 6.7577 - y2_output_loss: 9.6757 - y1_output_root_mean_squared_error: 2.6119 - y2_output_root_mean_squared_error: 3.1247 - val_loss: 15.4817 - val_y1_output_loss: 6.3185 - val_y2_output_loss: 8.7081 - val_y1_output_root_mean_squared_error: 2.5582 - val_y2_output_root_mean_squared_error: 2.9895
# Epoch 18/500
# 614/614 [==============================] - 0s 137us/sample - loss: 17.5218 - y1_output_loss: 6.9473 - y2_output_loss: 10.5813 - y1_output_root_mean_squared_error: 2.6292 - y2_output_root_mean_squared_error: 3.2572 - val_loss: 16.4001 - val_y1_output_loss: 6.7191 - val_y2_output_loss: 9.1560 - val_y1_output_root_mean_squared_error: 2.6354 - val_y2_output_root_mean_squared_error: 3.0748
# Epoch 19/500
# 614/614 [==============================] - 0s 131us/sample - loss: 18.1602 - y1_output_loss: 6.9146 - y2_output_loss: 11.5070 - y1_output_root_mean_squared_error: 2.6356 - y2_output_root_mean_squared_error: 3.3487 - val_loss: 58.4612 - val_y1_output_loss: 12.0575 - val_y2_output_loss: 46.1815 - val_y1_output_root_mean_squared_error: 3.4330 - val_y2_output_root_mean_squared_error: 6.8320
# Epoch 20/500
# 614/614 [==============================] - 0s 129us/sample - loss: 15.0430 - y1_output_loss: 6.1226 - y2_output_loss: 8.8104 - y1_output_root_mean_squared_error: 2.4824 - y2_output_root_mean_squared_error: 2.9800 - val_loss: 15.0592 - val_y1_output_loss: 5.5531 - val_y2_output_loss: 9.0988 - val_y1_output_root_mean_squared_error: 2.3748 - val_y2_output_root_mean_squared_error: 3.0691
# Epoch 21/500
# 614/614 [==============================] - 0s 134us/sample - loss: 15.7912 - y1_output_loss: 6.1613 - y2_output_loss: 9.6057 - y1_output_root_mean_squared_error: 2.4806 - y2_output_root_mean_squared_error: 3.1045 - val_loss: 19.1100 - val_y1_output_loss: 6.3589 - val_y2_output_loss: 12.2313 - val_y1_output_root_mean_squared_error: 2.5418 - val_y2_output_root_mean_squared_error: 3.5566
# Epoch 22/500
# 614/614 [==============================] - 0s 143us/sample - loss: 15.3129 - y1_output_loss: 5.8575 - y2_output_loss: 9.4186 - y1_output_root_mean_squared_error: 2.4270 - y2_output_root_mean_squared_error: 3.0696 - val_loss: 18.1357 - val_y1_output_loss: 6.6189 - val_y2_output_loss: 11.2478 - val_y1_output_root_mean_squared_error: 2.6101 - val_y2_output_root_mean_squared_error: 3.3649
# Epoch 23/500
# 614/614 [==============================] - 0s 130us/sample - loss: 18.3363 - y1_output_loss: 6.5116 - y2_output_loss: 11.8282 - y1_output_root_mean_squared_error: 2.5458 - y2_output_root_mean_squared_error: 3.4431 - val_loss: 14.1477 - val_y1_output_loss: 4.7686 - val_y2_output_loss: 8.9702 - val_y1_output_root_mean_squared_error: 2.2044 - val_y2_output_root_mean_squared_error: 3.0477
# Epoch 24/500
# 614/614 [==============================] - 0s 133us/sample - loss: 13.2891 - y1_output_loss: 5.3175 - y2_output_loss: 7.8591 - y1_output_root_mean_squared_error: 2.3155 - y2_output_root_mean_squared_error: 2.8156 - val_loss: 13.0821 - val_y1_output_loss: 4.9260 - val_y2_output_loss: 7.9032 - val_y1_output_root_mean_squared_error: 2.2158 - val_y2_output_root_mean_squared_error: 2.8587
# Epoch 25/500
# 614/614 [==============================] - 0s 133us/sample - loss: 12.0692 - y1_output_loss: 4.7225 - y2_output_loss: 7.2555 - y1_output_root_mean_squared_error: 2.1826 - y2_output_root_mean_squared_error: 2.7028 - val_loss: 11.3671 - val_y1_output_loss: 4.0770 - val_y2_output_loss: 6.9316 - val_y1_output_root_mean_squared_error: 2.0416 - val_y2_output_root_mean_squared_error: 2.6830
# Epoch 26/500
# 614/614 [==============================] - 0s 133us/sample - loss: 13.6884 - y1_output_loss: 4.8336 - y2_output_loss: 8.9149 - y1_output_root_mean_squared_error: 2.2055 - y2_output_root_mean_squared_error: 2.9705 - val_loss: 16.5152 - val_y1_output_loss: 5.0151 - val_y2_output_loss: 11.4107 - val_y1_output_root_mean_squared_error: 2.2693 - val_y2_output_root_mean_squared_error: 3.3713
# Epoch 27/500
# 614/614 [==============================] - 0s 131us/sample - loss: 12.4444 - y1_output_loss: 4.7331 - y2_output_loss: 7.6451 - y1_output_root_mean_squared_error: 2.1765 - y2_output_root_mean_squared_error: 2.7762 - val_loss: 28.2103 - val_y1_output_loss: 10.2006 - val_y2_output_loss: 17.7299 - val_y1_output_root_mean_squared_error: 3.1744 - val_y2_output_root_mean_squared_error: 4.2583
# Epoch 28/500
# 614/614 [==============================] - 0s 131us/sample - loss: 12.1516 - y1_output_loss: 4.5247 - y2_output_loss: 7.5168 - y1_output_root_mean_squared_error: 2.1363 - y2_output_root_mean_squared_error: 2.7546 - val_loss: 9.6764 - val_y1_output_loss: 3.7728 - val_y2_output_loss: 5.6159 - val_y1_output_root_mean_squared_error: 1.9654 - val_y2_output_root_mean_squared_error: 2.4112
# Epoch 29/500
# 614/614 [==============================] - 0s 130us/sample - loss: 11.9469 - y1_output_loss: 4.3677 - y2_output_loss: 7.7655 - y1_output_root_mean_squared_error: 2.0889 - y2_output_root_mean_squared_error: 2.7538 - val_loss: 30.8877 - val_y1_output_loss: 7.3164 - val_y2_output_loss: 23.4009 - val_y1_output_root_mean_squared_error: 2.7368 - val_y2_output_root_mean_squared_error: 4.8371
# Epoch 30/500
# 614/614 [==============================] - 0s 130us/sample - loss: 12.7812 - y1_output_loss: 4.4069 - y2_output_loss: 8.3036 - y1_output_root_mean_squared_error: 2.1063 - y2_output_root_mean_squared_error: 2.8887 - val_loss: 10.0590 - val_y1_output_loss: 3.8202 - val_y2_output_loss: 5.9334 - val_y1_output_root_mean_squared_error: 1.9775 - val_y2_output_root_mean_squared_error: 2.4796
# Epoch 31/500
# 614/614 [==============================] - 0s 131us/sample - loss: 10.9105 - y1_output_loss: 3.9593 - y2_output_loss: 6.8656 - y1_output_root_mean_squared_error: 1.9978 - y2_output_root_mean_squared_error: 2.6304 - val_loss: 8.5284 - val_y1_output_loss: 3.2371 - val_y2_output_loss: 5.0729 - val_y1_output_root_mean_squared_error: 1.8061 - val_y2_output_root_mean_squared_error: 2.2949
# Epoch 32/500
# 614/614 [==============================] - 0s 139us/sample - loss: 13.4842 - y1_output_loss: 4.3987 - y2_output_loss: 9.0086 - y1_output_root_mean_squared_error: 2.1004 - y2_output_root_mean_squared_error: 3.0121 - val_loss: 9.3102 - val_y1_output_loss: 3.4545 - val_y2_output_loss: 5.5687 - val_y1_output_root_mean_squared_error: 1.8809 - val_y2_output_root_mean_squared_error: 2.4026
# Epoch 33/500
# 614/614 [==============================] - 0s 137us/sample - loss: 9.1907 - y1_output_loss: 3.1989 - y2_output_loss: 5.9050 - y1_output_root_mean_squared_error: 1.7970 - y2_output_root_mean_squared_error: 2.4416 - val_loss: 8.3752 - val_y1_output_loss: 3.1697 - val_y2_output_loss: 5.0903 - val_y1_output_root_mean_squared_error: 1.7977 - val_y2_output_root_mean_squared_error: 2.2679
# Epoch 34/500
# 614/614 [==============================] - 0s 137us/sample - loss: 9.3634 - y1_output_loss: 3.3219 - y2_output_loss: 6.1422 - y1_output_root_mean_squared_error: 1.8079 - y2_output_root_mean_squared_error: 2.4688 - val_loss: 10.3118 - val_y1_output_loss: 4.1316 - val_y2_output_loss: 5.9765 - val_y1_output_root_mean_squared_error: 2.0618 - val_y2_output_root_mean_squared_error: 2.4619
# Epoch 35/500
# 614/614 [==============================] - 0s 134us/sample - loss: 8.6681 - y1_output_loss: 2.9713 - y2_output_loss: 5.6576 - y1_output_root_mean_squared_error: 1.7236 - y2_output_root_mean_squared_error: 2.3869 - val_loss: 8.9562 - val_y1_output_loss: 3.8270 - val_y2_output_loss: 4.8901 - val_y1_output_root_mean_squared_error: 1.9829 - val_y2_output_root_mean_squared_error: 2.2415
# Epoch 36/500
# 614/614 [==============================] - 0s 136us/sample - loss: 9.2546 - y1_output_loss: 3.0866 - y2_output_loss: 6.0944 - y1_output_root_mean_squared_error: 1.7648 - y2_output_root_mean_squared_error: 2.4779 - val_loss: 7.2882 - val_y1_output_loss: 2.5843 - val_y2_output_loss: 4.5372 - val_y1_output_root_mean_squared_error: 1.6188 - val_y2_output_root_mean_squared_error: 2.1605
# Epoch 37/500
# 614/614 [==============================] - 0s 135us/sample - loss: 7.5302 - y1_output_loss: 2.6146 - y2_output_loss: 4.9166 - y1_output_root_mean_squared_error: 1.6099 - y2_output_root_mean_squared_error: 2.2222 - val_loss: 7.4175 - val_y1_output_loss: 2.5664 - val_y2_output_loss: 4.6595 - val_y1_output_root_mean_squared_error: 1.6159 - val_y2_output_root_mean_squared_error: 2.1923
# Epoch 38/500
# 614/614 [==============================] - 0s 130us/sample - loss: 8.5791 - y1_output_loss: 2.6752 - y2_output_loss: 5.8463 - y1_output_root_mean_squared_error: 1.6426 - y2_output_root_mean_squared_error: 2.4250 - val_loss: 11.4746 - val_y1_output_loss: 4.5849 - val_y2_output_loss: 6.7699 - val_y1_output_root_mean_squared_error: 2.1652 - val_y2_output_root_mean_squared_error: 2.6051
# Epoch 39/500
# 614/614 [==============================] - 0s 129us/sample - loss: 9.1804 - y1_output_loss: 2.9252 - y2_output_loss: 6.2664 - y1_output_root_mean_squared_error: 1.7155 - y2_output_root_mean_squared_error: 2.4975 - val_loss: 8.0372 - val_y1_output_loss: 2.6660 - val_y2_output_loss: 5.1272 - val_y1_output_root_mean_squared_error: 1.6493 - val_y2_output_root_mean_squared_error: 2.3058
# Epoch 40/500
# 614/614 [==============================] - 0s 128us/sample - loss: 9.5975 - y1_output_loss: 3.2649 - y2_output_loss: 6.4248 - y1_output_root_mean_squared_error: 1.8048 - y2_output_root_mean_squared_error: 2.5180 - val_loss: 16.2550 - val_y1_output_loss: 3.1796 - val_y2_output_loss: 13.0315 - val_y1_output_root_mean_squared_error: 1.8014 - val_y2_output_root_mean_squared_error: 3.6069
# Epoch 41/500
# 614/614 [==============================] - 0s 131us/sample - loss: 8.1952 - y1_output_loss: 2.7567 - y2_output_loss: 5.3648 - y1_output_root_mean_squared_error: 1.6682 - y2_output_root_mean_squared_error: 2.3264 - val_loss: 5.7373 - val_y1_output_loss: 2.0545 - val_y2_output_loss: 3.5683 - val_y1_output_root_mean_squared_error: 1.4324 - val_y2_output_root_mean_squared_error: 1.9198
# Epoch 42/500
# 614/614 [==============================] - 0s 135us/sample - loss: 7.9173 - y1_output_loss: 2.5587 - y2_output_loss: 5.3037 - y1_output_root_mean_squared_error: 1.6027 - y2_output_root_mean_squared_error: 2.3127 - val_loss: 6.2738 - val_y1_output_loss: 2.2247 - val_y2_output_loss: 3.8938 - val_y1_output_root_mean_squared_error: 1.5084 - val_y2_output_root_mean_squared_error: 1.9996
# Epoch 43/500
# 614/614 [==============================] - 0s 136us/sample - loss: 7.9465 - y1_output_loss: 2.6157 - y2_output_loss: 5.3254 - y1_output_root_mean_squared_error: 1.6204 - y2_output_root_mean_squared_error: 2.3067 - val_loss: 7.6889 - val_y1_output_loss: 2.7595 - val_y2_output_loss: 4.7242 - val_y1_output_root_mean_squared_error: 1.6737 - val_y2_output_root_mean_squared_error: 2.2108
# Epoch 44/500
# 614/614 [==============================] - 0s 134us/sample - loss: 6.6386 - y1_output_loss: 2.2284 - y2_output_loss: 4.4373 - y1_output_root_mean_squared_error: 1.4833 - y2_output_root_mean_squared_error: 2.1068 - val_loss: 14.4759 - val_y1_output_loss: 4.4282 - val_y2_output_loss: 9.7321 - val_y1_output_root_mean_squared_error: 2.1033 - val_y2_output_root_mean_squared_error: 3.1705
# Epoch 45/500
# 614/614 [==============================] - 0s 130us/sample - loss: 8.5951 - y1_output_loss: 2.5120 - y2_output_loss: 6.0391 - y1_output_root_mean_squared_error: 1.5907 - y2_output_root_mean_squared_error: 2.4627 - val_loss: 11.1619 - val_y1_output_loss: 2.6371 - val_y2_output_loss: 8.1858 - val_y1_output_root_mean_squared_error: 1.6363 - val_y2_output_root_mean_squared_error: 2.9128
# Epoch 46/500
# 614/614 [==============================] - 0s 136us/sample - loss: 8.1204 - y1_output_loss: 2.4393 - y2_output_loss: 5.6170 - y1_output_root_mean_squared_error: 1.5676 - y2_output_root_mean_squared_error: 2.3797 - val_loss: 5.5226 - val_y1_output_loss: 1.9108 - val_y2_output_loss: 3.4932 - val_y1_output_root_mean_squared_error: 1.3938 - val_y2_output_root_mean_squared_error: 1.8921
# Epoch 47/500
# 614/614 [==============================] - 0s 136us/sample - loss: 8.8340 - y1_output_loss: 2.4218 - y2_output_loss: 6.3390 - y1_output_root_mean_squared_error: 1.5611 - y2_output_root_mean_squared_error: 2.5292 - val_loss: 8.7100 - val_y1_output_loss: 2.7861 - val_y2_output_loss: 5.6919 - val_y1_output_root_mean_squared_error: 1.6766 - val_y2_output_root_mean_squared_error: 2.4288
# Epoch 48/500
# 614/614 [==============================] - 0s 140us/sample - loss: 8.4604 - y1_output_loss: 2.4715 - y2_output_loss: 5.9481 - y1_output_root_mean_squared_error: 1.5674 - y2_output_root_mean_squared_error: 2.4502 - val_loss: 7.1646 - val_y1_output_loss: 2.6539 - val_y2_output_loss: 4.4193 - val_y1_output_root_mean_squared_error: 1.6465 - val_y2_output_root_mean_squared_error: 2.1104
# Epoch 49/500
# 614/614 [==============================] - 0s 130us/sample - loss: 5.9726 - y1_output_loss: 1.8250 - y2_output_loss: 4.1171 - y1_output_root_mean_squared_error: 1.3547 - y2_output_root_mean_squared_error: 2.0341 - val_loss: 5.5568 - val_y1_output_loss: 2.0060 - val_y2_output_loss: 3.4076 - val_y1_output_root_mean_squared_error: 1.4336 - val_y2_output_root_mean_squared_error: 1.8713
# Epoch 50/500
# 614/614 [==============================] - 0s 130us/sample - loss: 6.4037 - y1_output_loss: 1.9873 - y2_output_loss: 4.5648 - y1_output_root_mean_squared_error: 1.3992 - y2_output_root_mean_squared_error: 2.1085 - val_loss: 26.0361 - val_y1_output_loss: 5.4211 - val_y2_output_loss: 19.8521 - val_y1_output_root_mean_squared_error: 2.3504 - val_y2_output_root_mean_squared_error: 4.5290
# Epoch 51/500
# 614/614 [==============================] - 0s 132us/sample - loss: 9.3106 - y1_output_loss: 2.7322 - y2_output_loss: 6.6116 - y1_output_root_mean_squared_error: 1.6588 - y2_output_root_mean_squared_error: 2.5610 - val_loss: 21.1860 - val_y1_output_loss: 3.9835 - val_y2_output_loss: 17.0622 - val_y1_output_root_mean_squared_error: 2.0279 - val_y2_output_root_mean_squared_error: 4.1320
# Epoch 52/500
# 614/614 [==============================] - 0s 132us/sample - loss: 5.9239 - y1_output_loss: 1.8335 - y2_output_loss: 4.1589 - y1_output_root_mean_squared_error: 1.3487 - y2_output_root_mean_squared_error: 2.0260 - val_loss: 14.9429 - val_y1_output_loss: 5.7103 - val_y2_output_loss: 8.9176 - val_y1_output_root_mean_squared_error: 2.4288 - val_y2_output_root_mean_squared_error: 3.0073
# Epoch 53/500
# 614/614 [==============================] - 0s 139us/sample - loss: 6.1986 - y1_output_loss: 1.9930 - y2_output_loss: 4.2782 - y1_output_root_mean_squared_error: 1.3938 - y2_output_root_mean_squared_error: 2.0630 - val_loss: 5.8255 - val_y1_output_loss: 1.8770 - val_y2_output_loss: 3.8997 - val_y1_output_root_mean_squared_error: 1.3855 - val_y2_output_root_mean_squared_error: 1.9764
# Epoch 54/500
# 614/614 [==============================] - 0s 131us/sample - loss: 7.8171 - y1_output_loss: 2.3549 - y2_output_loss: 5.4982 - y1_output_root_mean_squared_error: 1.5204 - y2_output_root_mean_squared_error: 2.3464 - val_loss: 9.9847 - val_y1_output_loss: 3.7262 - val_y2_output_loss: 6.1398 - val_y1_output_root_mean_squared_error: 1.9597 - val_y2_output_root_mean_squared_error: 2.4788
# Epoch 55/500
# 614/614 [==============================] - 0s 128us/sample - loss: 7.7955 - y1_output_loss: 2.3032 - y2_output_loss: 5.4436 - y1_output_root_mean_squared_error: 1.5178 - y2_output_root_mean_squared_error: 2.3435 - val_loss: 4.7377 - val_y1_output_loss: 1.3890 - val_y2_output_loss: 3.2658 - val_y1_output_root_mean_squared_error: 1.1867 - val_y2_output_root_mean_squared_error: 1.8247
# Epoch 56/500
# 614/614 [==============================] - 0s 130us/sample - loss: 6.3609 - y1_output_loss: 1.9765 - y2_output_loss: 4.3947 - y1_output_root_mean_squared_error: 1.4000 - y2_output_root_mean_squared_error: 2.0978 - val_loss: 6.7388 - val_y1_output_loss: 2.3225 - val_y2_output_loss: 4.2325 - val_y1_output_root_mean_squared_error: 1.5464 - val_y2_output_root_mean_squared_error: 2.0851
# Epoch 57/500
# 614/614 [==============================] - 0s 129us/sample - loss: 5.4608 - y1_output_loss: 1.6620 - y2_output_loss: 3.8308 - y1_output_root_mean_squared_error: 1.2929 - y2_output_root_mean_squared_error: 1.9466 - val_loss: 5.1376 - val_y1_output_loss: 1.2339 - val_y2_output_loss: 3.7662 - val_y1_output_root_mean_squared_error: 1.1227 - val_y2_output_root_mean_squared_error: 1.9691
# Epoch 58/500
# 614/614 [==============================] - 0s 135us/sample - loss: 4.6899 - y1_output_loss: 1.4604 - y2_output_loss: 3.2445 - y1_output_root_mean_squared_error: 1.2032 - y2_output_root_mean_squared_error: 1.8006 - val_loss: 6.1672 - val_y1_output_loss: 2.6713 - val_y2_output_loss: 3.3126 - val_y1_output_root_mean_squared_error: 1.6599 - val_y2_output_root_mean_squared_error: 1.8472
# Epoch 59/500
# 614/614 [==============================] - 0s 131us/sample - loss: 4.8315 - y1_output_loss: 1.3747 - y2_output_loss: 3.5100 - y1_output_root_mean_squared_error: 1.1724 - y2_output_root_mean_squared_error: 1.8593 - val_loss: 6.8573 - val_y1_output_loss: 1.6076 - val_y2_output_loss: 5.4616 - val_y1_output_root_mean_squared_error: 1.2775 - val_y2_output_root_mean_squared_error: 2.2859
# Epoch 60/500
# 614/614 [==============================] - 0s 142us/sample - loss: 11.6512 - y1_output_loss: 3.6480 - y2_output_loss: 7.9192 - y1_output_root_mean_squared_error: 1.9147 - y2_output_root_mean_squared_error: 2.8258 - val_loss: 5.4962 - val_y1_output_loss: 1.8671 - val_y2_output_loss: 3.5498 - val_y1_output_root_mean_squared_error: 1.3881 - val_y2_output_root_mean_squared_error: 1.8893
# Epoch 61/500
# 614/614 [==============================] - 0s 140us/sample - loss: 5.1544 - y1_output_loss: 1.5022 - y2_output_loss: 3.6659 - y1_output_root_mean_squared_error: 1.2235 - y2_output_root_mean_squared_error: 1.9125 - val_loss: 9.1953 - val_y1_output_loss: 2.2531 - val_y2_output_loss: 7.0366 - val_y1_output_root_mean_squared_error: 1.5197 - val_y2_output_root_mean_squared_error: 2.6241
# Epoch 62/500
# 614/614 [==============================] - 0s 136us/sample - loss: 4.3303 - y1_output_loss: 1.3101 - y2_output_loss: 3.0095 - y1_output_root_mean_squared_error: 1.1485 - y2_output_root_mean_squared_error: 1.7353 - val_loss: 4.9530 - val_y1_output_loss: 1.1769 - val_y2_output_loss: 3.8732 - val_y1_output_root_mean_squared_error: 1.0996 - val_y2_output_root_mean_squared_error: 1.9349
# Epoch 63/500
# 614/614 [==============================] - 0s 136us/sample - loss: 4.5683 - y1_output_loss: 1.3324 - y2_output_loss: 3.2281 - y1_output_root_mean_squared_error: 1.1527 - y2_output_root_mean_squared_error: 1.7999 - val_loss: 7.6778 - val_y1_output_loss: 1.3002 - val_y2_output_loss: 6.1623 - val_y1_output_root_mean_squared_error: 1.1415 - val_y2_output_root_mean_squared_error: 2.5248
# Epoch 64/500
# 614/614 [==============================] - 0s 137us/sample - loss: 4.8496 - y1_output_loss: 1.2220 - y2_output_loss: 3.6185 - y1_output_root_mean_squared_error: 1.1061 - y2_output_root_mean_squared_error: 1.9042 - val_loss: 7.8167 - val_y1_output_loss: 1.9616 - val_y2_output_loss: 5.7176 - val_y1_output_root_mean_squared_error: 1.3920 - val_y2_output_root_mean_squared_error: 2.4247
# Epoch 65/500
# 614/614 [==============================] - 0s 132us/sample - loss: 4.0654 - y1_output_loss: 1.1148 - y2_output_loss: 2.9350 - y1_output_root_mean_squared_error: 1.0534 - y2_output_root_mean_squared_error: 1.7192 - val_loss: 6.1528 - val_y1_output_loss: 1.9188 - val_y2_output_loss: 4.2146 - val_y1_output_root_mean_squared_error: 1.4058 - val_y2_output_root_mean_squared_error: 2.0436
# Epoch 66/500
# 614/614 [==============================] - 0s 133us/sample - loss: 4.1534 - y1_output_loss: 1.1898 - y2_output_loss: 2.9969 - y1_output_root_mean_squared_error: 1.0960 - y2_output_root_mean_squared_error: 1.7182 - val_loss: 12.5138 - val_y1_output_loss: 2.4888 - val_y2_output_loss: 10.0836 - val_y1_output_root_mean_squared_error: 1.5983 - val_y2_output_root_mean_squared_error: 3.1558
# Epoch 67/500
# 614/614 [==============================] - 0s 141us/sample - loss: 4.2109 - y1_output_loss: 0.9848 - y2_output_loss: 3.2114 - y1_output_root_mean_squared_error: 0.9942 - y2_output_root_mean_squared_error: 1.7951 - val_loss: 10.9985 - val_y1_output_loss: 3.0276 - val_y2_output_loss: 7.6349 - val_y1_output_root_mean_squared_error: 1.7599 - val_y2_output_root_mean_squared_error: 2.8109
# Epoch 68/500
# 614/614 [==============================] - 0s 131us/sample - loss: 4.1085 - y1_output_loss: 1.2069 - y2_output_loss: 2.9226 - y1_output_root_mean_squared_error: 1.0974 - y2_output_root_mean_squared_error: 1.7042 - val_loss: 11.4627 - val_y1_output_loss: 3.1573 - val_y2_output_loss: 8.3092 - val_y1_output_root_mean_squared_error: 1.7981 - val_y2_output_root_mean_squared_error: 2.8687
# Epoch 69/500
# 614/614 [==============================] - 0s 131us/sample - loss: 6.6183 - y1_output_loss: 2.1815 - y2_output_loss: 4.3970 - y1_output_root_mean_squared_error: 1.4764 - y2_output_root_mean_squared_error: 2.1068 - val_loss: 3.9519 - val_y1_output_loss: 1.5938 - val_y2_output_loss: 2.3299 - val_y1_output_root_mean_squared_error: 1.2780 - val_y2_output_root_mean_squared_error: 1.5227
# Epoch 70/500
# 614/614 [==============================] - 0s 134us/sample - loss: 3.4210 - y1_output_loss: 0.8047 - y2_output_loss: 2.6163 - y1_output_root_mean_squared_error: 0.8911 - y2_output_root_mean_squared_error: 1.6208 - val_loss: 7.8861 - val_y1_output_loss: 2.6252 - val_y2_output_loss: 5.1570 - val_y1_output_root_mean_squared_error: 1.6079 - val_y2_output_root_mean_squared_error: 2.3024
# Epoch 71/500
# 614/614 [==============================] - 0s 129us/sample - loss: 4.7105 - y1_output_loss: 1.1474 - y2_output_loss: 3.5593 - y1_output_root_mean_squared_error: 1.0735 - y2_output_root_mean_squared_error: 1.8863 - val_loss: 5.6147 - val_y1_output_loss: 1.1155 - val_y2_output_loss: 4.3483 - val_y1_output_root_mean_squared_error: 1.0572 - val_y2_output_root_mean_squared_error: 2.1206
# Epoch 72/500
# 614/614 [==============================] - 0s 140us/sample - loss: 5.1192 - y1_output_loss: 1.5429 - y2_output_loss: 3.5904 - y1_output_root_mean_squared_error: 1.2445 - y2_output_root_mean_squared_error: 1.8896 - val_loss: 7.4179 - val_y1_output_loss: 1.5153 - val_y2_output_loss: 6.0350 - val_y1_output_root_mean_squared_error: 1.2410 - val_y2_output_root_mean_squared_error: 2.4244
# Epoch 73/500
# 614/614 [==============================] - 0s 128us/sample - loss: 3.3390 - y1_output_loss: 0.8132 - y2_output_loss: 2.5401 - y1_output_root_mean_squared_error: 0.9054 - y2_output_root_mean_squared_error: 1.5872 - val_loss: 10.0691 - val_y1_output_loss: 2.3091 - val_y2_output_loss: 7.4541 - val_y1_output_root_mean_squared_error: 1.5379 - val_y2_output_root_mean_squared_error: 2.7756
# Epoch 74/500
# 614/614 [==============================] - 0s 134us/sample - loss: 4.7471 - y1_output_loss: 1.2999 - y2_output_loss: 3.4210 - y1_output_root_mean_squared_error: 1.1441 - y2_output_root_mean_squared_error: 1.8542 - val_loss: 3.6634 - val_y1_output_loss: 0.7814 - val_y2_output_loss: 2.7918 - val_y1_output_root_mean_squared_error: 0.8899 - val_y2_output_root_mean_squared_error: 1.6946
# Epoch 75/500
# 614/614 [==============================] - 0s 135us/sample - loss: 3.3745 - y1_output_loss: 0.8852 - y2_output_loss: 2.4892 - y1_output_root_mean_squared_error: 0.9444 - y2_output_root_mean_squared_error: 1.5756 - val_loss: 4.8582 - val_y1_output_loss: 1.5133 - val_y2_output_loss: 3.2778 - val_y1_output_root_mean_squared_error: 1.2449 - val_y2_output_root_mean_squared_error: 1.8189
# Epoch 76/500
# 614/614 [==============================] - 0s 132us/sample - loss: 3.2882 - y1_output_loss: 0.8346 - y2_output_loss: 2.6116 - y1_output_root_mean_squared_error: 0.8949 - y2_output_root_mean_squared_error: 1.5771 - val_loss: 56.3403 - val_y1_output_loss: 21.8278 - val_y2_output_loss: 33.5442 - val_y1_output_root_mean_squared_error: 4.7347 - val_y2_output_root_mean_squared_error: 5.8244
# Epoch 77/500
# 614/614 [==============================] - 0s 132us/sample - loss: 8.9466 - y1_output_loss: 2.9271 - y2_output_loss: 5.9558 - y1_output_root_mean_squared_error: 1.7177 - y2_output_root_mean_squared_error: 2.4487 - val_loss: 7.7016 - val_y1_output_loss: 1.6486 - val_y2_output_loss: 5.8632 - val_y1_output_root_mean_squared_error: 1.2875 - val_y2_output_root_mean_squared_error: 2.4585
# Epoch 78/500
# 614/614 [==============================] - 0s 146us/sample - loss: 3.4459 - y1_output_loss: 0.8691 - y2_output_loss: 2.5480 - y1_output_root_mean_squared_error: 0.9350 - y2_output_root_mean_squared_error: 1.6037 - val_loss: 2.9668 - val_y1_output_loss: 0.8046 - val_y2_output_loss: 2.1732 - val_y1_output_root_mean_squared_error: 0.9023 - val_y2_output_root_mean_squared_error: 1.4672
# Epoch 79/500
# 614/614 [==============================] - 0s 139us/sample - loss: 3.3683 - y1_output_loss: 0.8507 - y2_output_loss: 2.5309 - y1_output_root_mean_squared_error: 0.9241 - y2_output_root_mean_squared_error: 1.5856 - val_loss: 5.0471 - val_y1_output_loss: 0.7459 - val_y2_output_loss: 4.1590 - val_y1_output_root_mean_squared_error: 0.8623 - val_y2_output_root_mean_squared_error: 2.0745
# Epoch 80/500
# 614/614 [==============================] - 0s 134us/sample - loss: 3.8298 - y1_output_loss: 0.9053 - y2_output_loss: 2.9090 - y1_output_root_mean_squared_error: 0.9520 - y2_output_root_mean_squared_error: 1.7098 - val_loss: 4.4743 - val_y1_output_loss: 1.7185 - val_y2_output_loss: 2.7669 - val_y1_output_root_mean_squared_error: 1.2951 - val_y2_output_root_mean_squared_error: 1.6724
# Epoch 81/500
# 614/614 [==============================] - 0s 135us/sample - loss: 3.8380 - y1_output_loss: 1.0492 - y2_output_loss: 2.7930 - y1_output_root_mean_squared_error: 1.0209 - y2_output_root_mean_squared_error: 1.6721 - val_loss: 15.9353 - val_y1_output_loss: 4.3038 - val_y2_output_loss: 11.5686 - val_y1_output_root_mean_squared_error: 2.0483 - val_y2_output_root_mean_squared_error: 3.4264
# Epoch 82/500
# 614/614 [==============================] - 0s 132us/sample - loss: 2.8226 - y1_output_loss: 0.7007 - y2_output_loss: 2.1922 - y1_output_root_mean_squared_error: 0.8385 - y2_output_root_mean_squared_error: 1.4559 - val_loss: 5.0538 - val_y1_output_loss: 1.3242 - val_y2_output_loss: 3.6673 - val_y1_output_root_mean_squared_error: 1.1631 - val_y2_output_root_mean_squared_error: 1.9238
# Epoch 83/500
# 614/614 [==============================] - 0s 130us/sample - loss: 3.5836 - y1_output_loss: 1.0333 - y2_output_loss: 2.5472 - y1_output_root_mean_squared_error: 1.0205 - y2_output_root_mean_squared_error: 1.5944 - val_loss: 4.0076 - val_y1_output_loss: 0.9906 - val_y2_output_loss: 3.1101 - val_y1_output_root_mean_squared_error: 1.0056 - val_y2_output_root_mean_squared_error: 1.7310
# Epoch 84/500
# 614/614 [==============================] - 0s 131us/sample - loss: 3.8999 - y1_output_loss: 0.9413 - y2_output_loss: 2.9709 - y1_output_root_mean_squared_error: 0.9746 - y2_output_root_mean_squared_error: 1.7176 - val_loss: 8.0223 - val_y1_output_loss: 2.2887 - val_y2_output_loss: 5.6006 - val_y1_output_root_mean_squared_error: 1.5387 - val_y2_output_root_mean_squared_error: 2.3780
# Epoch 85/500
# 614/614 [==============================] - 0s 128us/sample - loss: 4.8152 - y1_output_loss: 1.3825 - y2_output_loss: 3.5715 - y1_output_root_mean_squared_error: 1.1556 - y2_output_root_mean_squared_error: 1.8654 - val_loss: 14.9040 - val_y1_output_loss: 5.4200 - val_y2_output_loss: 9.1492 - val_y1_output_root_mean_squared_error: 2.3480 - val_y2_output_root_mean_squared_error: 3.0645
# Epoch 86/500
# 614/614 [==============================] - 0s 129us/sample - loss: 5.0708 - y1_output_loss: 1.5250 - y2_output_loss: 3.5194 - y1_output_root_mean_squared_error: 1.2406 - y2_output_root_mean_squared_error: 1.8793 - val_loss: 2.6637 - val_y1_output_loss: 0.8202 - val_y2_output_loss: 1.8235 - val_y1_output_root_mean_squared_error: 0.9058 - val_y2_output_root_mean_squared_error: 1.3577
# Epoch 87/500
# 614/614 [==============================] - 0s 128us/sample - loss: 2.5729 - y1_output_loss: 0.6255 - y2_output_loss: 1.9280 - y1_output_root_mean_squared_error: 0.7920 - y2_output_root_mean_squared_error: 1.3948 - val_loss: 2.7219 - val_y1_output_loss: 0.6869 - val_y2_output_loss: 2.0327 - val_y1_output_root_mean_squared_error: 0.8393 - val_y2_output_root_mean_squared_error: 1.4203
# Epoch 88/500
# 614/614 [==============================] - 0s 127us/sample - loss: 4.1785 - y1_output_loss: 1.0253 - y2_output_loss: 3.1928 - y1_output_root_mean_squared_error: 1.0168 - y2_output_root_mean_squared_error: 1.7733 - val_loss: 6.4010 - val_y1_output_loss: 1.3147 - val_y2_output_loss: 4.9040 - val_y1_output_root_mean_squared_error: 1.1621 - val_y2_output_root_mean_squared_error: 2.2473
# Epoch 89/500
# 614/614 [==============================] - 0s 129us/sample - loss: 3.2287 - y1_output_loss: 0.7673 - y2_output_loss: 2.4355 - y1_output_root_mean_squared_error: 0.8782 - y2_output_root_mean_squared_error: 1.5676 - val_loss: 2.2872 - val_y1_output_loss: 0.5078 - val_y2_output_loss: 1.7845 - val_y1_output_root_mean_squared_error: 0.7192 - val_y2_output_root_mean_squared_error: 1.3304
# Epoch 90/500
# 614/614 [==============================] - 0s 128us/sample - loss: 2.6925 - y1_output_loss: 0.6306 - y2_output_loss: 2.0763 - y1_output_root_mean_squared_error: 0.7912 - y2_output_root_mean_squared_error: 1.4375 - val_loss: 3.3155 - val_y1_output_loss: 0.8033 - val_y2_output_loss: 2.4604 - val_y1_output_root_mean_squared_error: 0.9017 - val_y2_output_root_mean_squared_error: 1.5819
# Epoch 91/500
# 614/614 [==============================] - 0s 127us/sample - loss: 3.0449 - y1_output_loss: 0.7392 - y2_output_loss: 2.2897 - y1_output_root_mean_squared_error: 0.8626 - y2_output_root_mean_squared_error: 1.5168 - val_loss: 4.0353 - val_y1_output_loss: 0.5369 - val_y2_output_loss: 3.3892 - val_y1_output_root_mean_squared_error: 0.7347 - val_y2_output_root_mean_squared_error: 1.8696
# Epoch 92/500
# 614/614 [==============================] - 0s 130us/sample - loss: 5.0771 - y1_output_loss: 1.3606 - y2_output_loss: 3.6761 - y1_output_root_mean_squared_error: 1.1695 - y2_output_root_mean_squared_error: 1.9260 - val_loss: 2.7692 - val_y1_output_loss: 0.6559 - val_y2_output_loss: 2.1271 - val_y1_output_root_mean_squared_error: 0.8164 - val_y2_output_root_mean_squared_error: 1.4500
# Epoch 93/500
# 614/614 [==============================] - 0s 129us/sample - loss: 3.0705 - y1_output_loss: 0.7495 - y2_output_loss: 2.3348 - y1_output_root_mean_squared_error: 0.8655 - y2_output_root_mean_squared_error: 1.5236 - val_loss: 9.7803 - val_y1_output_loss: 3.1722 - val_y2_output_loss: 6.3473 - val_y1_output_root_mean_squared_error: 1.7964 - val_y2_output_root_mean_squared_error: 2.5600
# Epoch 94/500
# 614/614 [==============================] - 0s 134us/sample - loss: 3.9677 - y1_output_loss: 1.0775 - y2_output_loss: 2.8833 - y1_output_root_mean_squared_error: 1.0407 - y2_output_root_mean_squared_error: 1.6984 - val_loss: 4.6574 - val_y1_output_loss: 1.5840 - val_y2_output_loss: 3.2555 - val_y1_output_root_mean_squared_error: 1.2513 - val_y2_output_root_mean_squared_error: 1.7583
# Epoch 95/500
# 614/614 [==============================] - 0s 134us/sample - loss: 2.2809 - y1_output_loss: 0.5462 - y2_output_loss: 1.7180 - y1_output_root_mean_squared_error: 0.7414 - y2_output_root_mean_squared_error: 1.3157 - val_loss: 2.2634 - val_y1_output_loss: 0.5304 - val_y2_output_loss: 1.7595 - val_y1_output_root_mean_squared_error: 0.7286 - val_y2_output_root_mean_squared_error: 1.3163
# Epoch 96/500
# 614/614 [==============================] - 0s 131us/sample - loss: 4.7075 - y1_output_loss: 1.3192 - y2_output_loss: 3.4364 - y1_output_root_mean_squared_error: 1.1525 - y2_output_root_mean_squared_error: 1.8383 - val_loss: 16.2488 - val_y1_output_loss: 2.7072 - val_y2_output_loss: 13.0712 - val_y1_output_root_mean_squared_error: 1.6639 - val_y2_output_root_mean_squared_error: 3.6715
# Epoch 97/500
# 614/614 [==============================] - 0s 135us/sample - loss: 3.5850 - y1_output_loss: 0.8014 - y2_output_loss: 2.7897 - y1_output_root_mean_squared_error: 0.8934 - y2_output_root_mean_squared_error: 1.6693 - val_loss: 2.9471 - val_y1_output_loss: 0.5887 - val_y2_output_loss: 2.3948 - val_y1_output_root_mean_squared_error: 0.7672 - val_y2_output_root_mean_squared_error: 1.5357
# Epoch 98/500
# 614/614 [==============================] - 0s 135us/sample - loss: 3.0920 - y1_output_loss: 0.8353 - y2_output_loss: 2.2477 - y1_output_root_mean_squared_error: 0.9112 - y2_output_root_mean_squared_error: 1.5039 - val_loss: 2.3284 - val_y1_output_loss: 0.4486 - val_y2_output_loss: 1.9155 - val_y1_output_root_mean_squared_error: 0.6786 - val_y2_output_root_mean_squared_error: 1.3667
# Epoch 99/500
# 614/614 [==============================] - 0s 134us/sample - loss: 2.3592 - y1_output_loss: 0.5596 - y2_output_loss: 1.7905 - y1_output_root_mean_squared_error: 0.7504 - y2_output_root_mean_squared_error: 1.3402 - val_loss: 5.0944 - val_y1_output_loss: 1.1014 - val_y2_output_loss: 3.8990 - val_y1_output_root_mean_squared_error: 1.0601 - val_y2_output_root_mean_squared_error: 1.9927
# Epoch 100/500
# 614/614 [==============================] - 0s 131us/sample - loss: 3.6245 - y1_output_loss: 0.7854 - y2_output_loss: 2.8241 - y1_output_root_mean_squared_error: 0.8899 - y2_output_root_mean_squared_error: 1.6830 - val_loss: 3.9210 - val_y1_output_loss: 0.5988 - val_y2_output_loss: 3.2167 - val_y1_output_root_mean_squared_error: 0.7782 - val_y2_output_root_mean_squared_error: 1.8208
# Epoch 101/500
# 614/614 [==============================] - 0s 136us/sample - loss: 2.1455 - y1_output_loss: 0.5042 - y2_output_loss: 1.6258 - y1_output_root_mean_squared_error: 0.7126 - y2_output_root_mean_squared_error: 1.2797 - val_loss: 2.0995 - val_y1_output_loss: 0.4021 - val_y2_output_loss: 1.6882 - val_y1_output_root_mean_squared_error: 0.6407 - val_y2_output_root_mean_squared_error: 1.2996
# Epoch 102/500
# 614/614 [==============================] - 0s 133us/sample - loss: 2.4235 - y1_output_loss: 0.5239 - y2_output_loss: 1.8888 - y1_output_root_mean_squared_error: 0.7228 - y2_output_root_mean_squared_error: 1.3788 - val_loss: 2.2240 - val_y1_output_loss: 0.5141 - val_y2_output_loss: 1.7079 - val_y1_output_root_mean_squared_error: 0.7254 - val_y2_output_root_mean_squared_error: 1.3030
# Epoch 103/500
# 614/614 [==============================] - 0s 135us/sample - loss: 2.1510 - y1_output_loss: 0.4775 - y2_output_loss: 1.6925 - y1_output_root_mean_squared_error: 0.6907 - y2_output_root_mean_squared_error: 1.2938 - val_loss: 2.6968 - val_y1_output_loss: 0.5543 - val_y2_output_loss: 2.1235 - val_y1_output_root_mean_squared_error: 0.7427 - val_y2_output_root_mean_squared_error: 1.4647
# Epoch 104/500
# 614/614 [==============================] - 0s 134us/sample - loss: 2.4812 - y1_output_loss: 0.5730 - y2_output_loss: 1.8892 - y1_output_root_mean_squared_error: 0.7593 - y2_output_root_mean_squared_error: 1.3801 - val_loss: 2.5304 - val_y1_output_loss: 0.5397 - val_y2_output_loss: 1.9961 - val_y1_output_root_mean_squared_error: 0.7405 - val_y2_output_root_mean_squared_error: 1.4079
# Epoch 105/500
# 614/614 [==============================] - 0s 134us/sample - loss: 2.6105 - y1_output_loss: 0.6373 - y2_output_loss: 2.0782 - y1_output_root_mean_squared_error: 0.8006 - y2_output_root_mean_squared_error: 1.4034 - val_loss: 35.5308 - val_y1_output_loss: 4.3397 - val_y2_output_loss: 31.5473 - val_y1_output_root_mean_squared_error: 2.0915 - val_y2_output_root_mean_squared_error: 5.5818
# Epoch 106/500
# 614/614 [==============================] - 0s 137us/sample - loss: 6.9531 - y1_output_loss: 1.6795 - y2_output_loss: 5.2545 - y1_output_root_mean_squared_error: 1.3000 - y2_output_root_mean_squared_error: 2.2942 - val_loss: 4.3344 - val_y1_output_loss: 1.0805 - val_y2_output_loss: 3.4198 - val_y1_output_root_mean_squared_error: 1.0384 - val_y2_output_root_mean_squared_error: 1.8045
# Epoch 107/500
# 614/614 [==============================] - 0s 127us/sample - loss: 2.2991 - y1_output_loss: 0.5131 - y2_output_loss: 1.8100 - y1_output_root_mean_squared_error: 0.7125 - y2_output_root_mean_squared_error: 1.3384 - val_loss: 2.8755 - val_y1_output_loss: 0.7670 - val_y2_output_loss: 2.1079 - val_y1_output_root_mean_squared_error: 0.8739 - val_y2_output_root_mean_squared_error: 1.4532
# Epoch 108/500
# 614/614 [==============================] - 0s 127us/sample - loss: 2.4363 - y1_output_loss: 0.5657 - y2_output_loss: 1.8555 - y1_output_root_mean_squared_error: 0.7557 - y2_output_root_mean_squared_error: 1.3657 - val_loss: 2.4231 - val_y1_output_loss: 0.5638 - val_y2_output_loss: 1.8121 - val_y1_output_root_mean_squared_error: 0.7561 - val_y2_output_root_mean_squared_error: 1.3606
# Epoch 109/500
# 614/614 [==============================] - 0s 127us/sample - loss: 2.4278 - y1_output_loss: 0.5276 - y2_output_loss: 1.8887 - y1_output_root_mean_squared_error: 0.7277 - y2_output_root_mean_squared_error: 1.3778 - val_loss: 3.2659 - val_y1_output_loss: 0.5855 - val_y2_output_loss: 2.7702 - val_y1_output_root_mean_squared_error: 0.7708 - val_y2_output_root_mean_squared_error: 1.6345
# Epoch 110/500
# 614/614 [==============================] - 0s 128us/sample - loss: 2.0710 - y1_output_loss: 0.4540 - y2_output_loss: 1.6072 - y1_output_root_mean_squared_error: 0.6765 - y2_output_root_mean_squared_error: 1.2702 - val_loss: 2.7442 - val_y1_output_loss: 0.4686 - val_y2_output_loss: 2.3553 - val_y1_output_root_mean_squared_error: 0.6886 - val_y2_output_root_mean_squared_error: 1.5067
# Epoch 111/500
# 614/614 [==============================] - 0s 127us/sample - loss: 2.5159 - y1_output_loss: 0.6368 - y2_output_loss: 1.8720 - y1_output_root_mean_squared_error: 0.8012 - y2_output_root_mean_squared_error: 1.3689 - val_loss: 3.8064 - val_y1_output_loss: 1.0474 - val_y2_output_loss: 2.6841 - val_y1_output_root_mean_squared_error: 1.0354 - val_y2_output_root_mean_squared_error: 1.6536
# Epoch 112/500
# 614/614 [==============================] - 0s 127us/sample - loss: 3.4556 - y1_output_loss: 0.8926 - y2_output_loss: 2.5710 - y1_output_root_mean_squared_error: 0.9398 - y2_output_root_mean_squared_error: 1.6039 - val_loss: 6.4832 - val_y1_output_loss: 2.1806 - val_y2_output_loss: 4.1723 - val_y1_output_root_mean_squared_error: 1.4828 - val_y2_output_root_mean_squared_error: 2.0699
# Epoch 113/500
# 614/614 [==============================] - 0s 127us/sample - loss: 1.9069 - y1_output_loss: 0.4578 - y2_output_loss: 1.4589 - y1_output_root_mean_squared_error: 0.6789 - y2_output_root_mean_squared_error: 1.2025 - val_loss: 2.7906 - val_y1_output_loss: 0.8560 - val_y2_output_loss: 1.8772 - val_y1_output_root_mean_squared_error: 0.9252 - val_y2_output_root_mean_squared_error: 1.3909
# Epoch 114/500
# 614/614 [==============================] - 0s 128us/sample - loss: 2.3002 - y1_output_loss: 0.4993 - y2_output_loss: 1.7822 - y1_output_root_mean_squared_error: 0.7087 - y2_output_root_mean_squared_error: 1.3409 - val_loss: 2.4331 - val_y1_output_loss: 0.4916 - val_y2_output_loss: 1.8831 - val_y1_output_root_mean_squared_error: 0.7049 - val_y2_output_root_mean_squared_error: 1.3915
# Epoch 115/500
# 614/614 [==============================] - 0s 128us/sample - loss: 5.3941 - y1_output_loss: 1.3739 - y2_output_loss: 3.9733 - y1_output_root_mean_squared_error: 1.1776 - y2_output_root_mean_squared_error: 2.0018 - val_loss: 2.2417 - val_y1_output_loss: 0.4657 - val_y2_output_loss: 1.7810 - val_y1_output_root_mean_squared_error: 0.6920 - val_y2_output_root_mean_squared_error: 1.3277
# Epoch 116/500
# 614/614 [==============================] - 0s 130us/sample - loss: 2.4567 - y1_output_loss: 0.5738 - y2_output_loss: 1.8762 - y1_output_root_mean_squared_error: 0.7594 - y2_output_root_mean_squared_error: 1.3711 - val_loss: 2.2670 - val_y1_output_loss: 0.4712 - val_y2_output_loss: 1.7863 - val_y1_output_root_mean_squared_error: 0.6909 - val_y2_output_root_mean_squared_error: 1.3378
# Epoch 117/500
# 614/614 [==============================] - 0s 127us/sample - loss: 2.5423 - y1_output_loss: 0.6199 - y2_output_loss: 1.9546 - y1_output_root_mean_squared_error: 0.7909 - y2_output_root_mean_squared_error: 1.3845 - val_loss: 8.0133 - val_y1_output_loss: 1.1657 - val_y2_output_loss: 6.8996 - val_y1_output_root_mean_squared_error: 1.0959 - val_y2_output_root_mean_squared_error: 2.6100
# Epoch 118/500
# 614/614 [==============================] - 0s 127us/sample - loss: 2.7817 - y1_output_loss: 0.6146 - y2_output_loss: 2.1506 - y1_output_root_mean_squared_error: 0.7864 - y2_output_root_mean_squared_error: 1.4708 - val_loss: 2.7077 - val_y1_output_loss: 0.5884 - val_y2_output_loss: 2.1885 - val_y1_output_root_mean_squared_error: 0.7750 - val_y2_output_root_mean_squared_error: 1.4516
# Epoch 119/500
# 614/614 [==============================] - 0s 130us/sample - loss: 1.7324 - y1_output_loss: 0.3886 - y2_output_loss: 1.3509 - y1_output_root_mean_squared_error: 0.6257 - y2_output_root_mean_squared_error: 1.1579 - val_loss: 4.4063 - val_y1_output_loss: 0.4861 - val_y2_output_loss: 3.7939 - val_y1_output_root_mean_squared_error: 0.7006 - val_y2_output_root_mean_squared_error: 1.9788
# Epoch 120/500
# 614/614 [==============================] - 0s 128us/sample - loss: 2.0149 - y1_output_loss: 0.4775 - y2_output_loss: 1.5386 - y1_output_root_mean_squared_error: 0.6857 - y2_output_root_mean_squared_error: 1.2428 - val_loss: 5.2474 - val_y1_output_loss: 1.5333 - val_y2_output_loss: 3.5516 - val_y1_output_root_mean_squared_error: 1.2579 - val_y2_output_root_mean_squared_error: 1.9144
# Epoch 121/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.3619 - y1_output_loss: 0.1037 - y2_output_loss: 0.2599 - y1_output_root_mean_squared_error: 0.3228 - y2_output_root_mean_squared_error: 0.5076 - val_loss: 1.3951 - val_y1_output_loss: 0.3205 - val_y2_output_loss: 1.0407 - val_y1_output_root_mean_squared_error: 0.5752 - val_y2_output_root_mean_squared_error: 1.0316
# Epoch 462/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.6538 - y1_output_loss: 0.1774 - y2_output_loss: 0.4743 - y1_output_root_mean_squared_error: 0.4227 - y2_output_root_mean_squared_error: 0.6893 - val_loss: 0.8330 - val_y1_output_loss: 0.2578 - val_y2_output_loss: 0.5549 - val_y1_output_root_mean_squared_error: 0.5167 - val_y2_output_root_mean_squared_error: 0.7523
# Epoch 463/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.4345 - y1_output_loss: 0.1167 - y2_output_loss: 0.3197 - y1_output_root_mean_squared_error: 0.3410 - y2_output_root_mean_squared_error: 0.5641 - val_loss: 2.2262 - val_y1_output_loss: 0.4562 - val_y2_output_loss: 1.7189 - val_y1_output_root_mean_squared_error: 0.6861 - val_y2_output_root_mean_squared_error: 1.3249
# Epoch 464/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.4212 - y1_output_loss: 0.1125 - y2_output_loss: 0.3085 - y1_output_root_mean_squared_error: 0.3360 - y2_output_root_mean_squared_error: 0.5553 - val_loss: 0.9261 - val_y1_output_loss: 0.2687 - val_y2_output_loss: 0.6349 - val_y1_output_root_mean_squared_error: 0.5268 - val_y2_output_root_mean_squared_error: 0.8054
# Epoch 465/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.3778 - y1_output_loss: 0.1137 - y2_output_loss: 0.2676 - y1_output_root_mean_squared_error: 0.3356 - y2_output_root_mean_squared_error: 0.5149 - val_loss: 0.9683 - val_y1_output_loss: 0.3190 - val_y2_output_loss: 0.6401 - val_y1_output_root_mean_squared_error: 0.5727 - val_y2_output_root_mean_squared_error: 0.8002
# Epoch 466/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.4629 - y1_output_loss: 0.1293 - y2_output_loss: 0.3329 - y1_output_root_mean_squared_error: 0.3608 - y2_output_root_mean_squared_error: 0.5768 - val_loss: 1.5450 - val_y1_output_loss: 0.2990 - val_y2_output_loss: 1.2763 - val_y1_output_root_mean_squared_error: 0.5511 - val_y2_output_root_mean_squared_error: 1.1141
# Epoch 467/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.3559 - y1_output_loss: 0.1132 - y2_output_loss: 0.2402 - y1_output_root_mean_squared_error: 0.3372 - y2_output_root_mean_squared_error: 0.4921 - val_loss: 0.8544 - val_y1_output_loss: 0.2945 - val_y2_output_loss: 0.5415 - val_y1_output_root_mean_squared_error: 0.5523 - val_y2_output_root_mean_squared_error: 0.7412
# Epoch 468/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.4279 - y1_output_loss: 0.1280 - y2_output_loss: 0.2971 - y1_output_root_mean_squared_error: 0.3589 - y2_output_root_mean_squared_error: 0.5469 - val_loss: 0.9190 - val_y1_output_loss: 0.3380 - val_y2_output_loss: 0.5648 - val_y1_output_root_mean_squared_error: 0.5916 - val_y2_output_root_mean_squared_error: 0.7543
# Epoch 469/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.6648 - y1_output_loss: 0.2046 - y2_output_loss: 0.4566 - y1_output_root_mean_squared_error: 0.4531 - y2_output_root_mean_squared_error: 0.6779 - val_loss: 0.8010 - val_y1_output_loss: 0.2863 - val_y2_output_loss: 0.5026 - val_y1_output_root_mean_squared_error: 0.5440 - val_y2_output_root_mean_squared_error: 0.7107
# Epoch 470/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.6902 - y1_output_loss: 0.1631 - y2_output_loss: 0.5215 - y1_output_root_mean_squared_error: 0.4052 - y2_output_root_mean_squared_error: 0.7253 - val_loss: 0.7971 - val_y1_output_loss: 0.2743 - val_y2_output_loss: 0.5099 - val_y1_output_root_mean_squared_error: 0.5331 - val_y2_output_root_mean_squared_error: 0.7161
# Epoch 471/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.4359 - y1_output_loss: 0.1360 - y2_output_loss: 0.3033 - y1_output_root_mean_squared_error: 0.3683 - y2_output_root_mean_squared_error: 0.5479 - val_loss: 2.0428 - val_y1_output_loss: 0.4883 - val_y2_output_loss: 1.4951 - val_y1_output_root_mean_squared_error: 0.7088 - val_y2_output_root_mean_squared_error: 1.2411
# Epoch 472/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.5567 - y1_output_loss: 0.1494 - y2_output_loss: 0.4036 - y1_output_root_mean_squared_error: 0.3880 - y2_output_root_mean_squared_error: 0.6373 - val_loss: 0.8183 - val_y1_output_loss: 0.3068 - val_y2_output_loss: 0.4941 - val_y1_output_root_mean_squared_error: 0.5639 - val_y2_output_root_mean_squared_error: 0.7074
# Epoch 473/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.3715 - y1_output_loss: 0.1137 - y2_output_loss: 0.2712 - y1_output_root_mean_squared_error: 0.3339 - y2_output_root_mean_squared_error: 0.5099 - val_loss: 1.7085 - val_y1_output_loss: 0.3872 - val_y2_output_loss: 1.3063 - val_y1_output_root_mean_squared_error: 0.6253 - val_y2_output_root_mean_squared_error: 1.1478
# Epoch 474/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.4582 - y1_output_loss: 0.1372 - y2_output_loss: 0.3175 - y1_output_root_mean_squared_error: 0.3722 - y2_output_root_mean_squared_error: 0.5654 - val_loss: 0.8964 - val_y1_output_loss: 0.3221 - val_y2_output_loss: 0.5496 - val_y1_output_root_mean_squared_error: 0.5752 - val_y2_output_root_mean_squared_error: 0.7520
# Epoch 475/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.3342 - y1_output_loss: 0.1129 - y2_output_loss: 0.2226 - y1_output_root_mean_squared_error: 0.3357 - y2_output_root_mean_squared_error: 0.4707 - val_loss: 1.0132 - val_y1_output_loss: 0.3112 - val_y2_output_loss: 0.6783 - val_y1_output_root_mean_squared_error: 0.5648 - val_y2_output_root_mean_squared_error: 0.8332
# Epoch 476/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.6476 - y1_output_loss: 0.1594 - y2_output_loss: 0.5027 - y1_output_root_mean_squared_error: 0.3908 - y2_output_root_mean_squared_error: 0.7035 - val_loss: 3.0321 - val_y1_output_loss: 0.9862 - val_y2_output_loss: 1.9597 - val_y1_output_root_mean_squared_error: 1.0085 - val_y2_output_root_mean_squared_error: 1.4195
# Epoch 477/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.3881 - y1_output_loss: 0.1263 - y2_output_loss: 0.2602 - y1_output_root_mean_squared_error: 0.3560 - y2_output_root_mean_squared_error: 0.5113 - val_loss: 1.0025 - val_y1_output_loss: 0.3041 - val_y2_output_loss: 0.6880 - val_y1_output_root_mean_squared_error: 0.5594 - val_y2_output_root_mean_squared_error: 0.8304
# Epoch 478/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.3655 - y1_output_loss: 0.1161 - y2_output_loss: 0.2472 - y1_output_root_mean_squared_error: 0.3421 - y2_output_root_mean_squared_error: 0.4985 - val_loss: 1.0077 - val_y1_output_loss: 0.3070 - val_y2_output_loss: 0.6759 - val_y1_output_root_mean_squared_error: 0.5638 - val_y2_output_root_mean_squared_error: 0.8306
# Epoch 479/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.3692 - y1_output_loss: 0.1263 - y2_output_loss: 0.2402 - y1_output_root_mean_squared_error: 0.3566 - y2_output_root_mean_squared_error: 0.4921 - val_loss: 0.8060 - val_y1_output_loss: 0.2689 - val_y2_output_loss: 0.5124 - val_y1_output_root_mean_squared_error: 0.5273 - val_y2_output_root_mean_squared_error: 0.7266
# Epoch 480/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.3958 - y1_output_loss: 0.1178 - y2_output_loss: 0.2786 - y1_output_root_mean_squared_error: 0.3445 - y2_output_root_mean_squared_error: 0.5265 - val_loss: 0.9877 - val_y1_output_loss: 0.3386 - val_y2_output_loss: 0.6333 - val_y1_output_root_mean_squared_error: 0.5890 - val_y2_output_root_mean_squared_error: 0.8005
# Epoch 481/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.4469 - y1_output_loss: 0.1282 - y2_output_loss: 0.3152 - y1_output_root_mean_squared_error: 0.3597 - y2_output_root_mean_squared_error: 0.5635 - val_loss: 0.9086 - val_y1_output_loss: 0.3282 - val_y2_output_loss: 0.5692 - val_y1_output_root_mean_squared_error: 0.5829 - val_y2_output_root_mean_squared_error: 0.7542
# Epoch 482/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.3414 - y1_output_loss: 0.1035 - y2_output_loss: 0.2358 - y1_output_root_mean_squared_error: 0.3227 - y2_output_root_mean_squared_error: 0.4872 - val_loss: 0.7586 - val_y1_output_loss: 0.2660 - val_y2_output_loss: 0.4752 - val_y1_output_root_mean_squared_error: 0.5251 - val_y2_output_root_mean_squared_error: 0.6949
# Epoch 483/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.3445 - y1_output_loss: 0.1005 - y2_output_loss: 0.2451 - y1_output_root_mean_squared_error: 0.3177 - y2_output_root_mean_squared_error: 0.4935 - val_loss: 0.8145 - val_y1_output_loss: 0.2642 - val_y2_output_loss: 0.5411 - val_y1_output_root_mean_squared_error: 0.5221 - val_y2_output_root_mean_squared_error: 0.7362
# Epoch 484/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.3544 - y1_output_loss: 0.1147 - y2_output_loss: 0.2393 - y1_output_root_mean_squared_error: 0.3399 - y2_output_root_mean_squared_error: 0.4888 - val_loss: 0.7829 - val_y1_output_loss: 0.2769 - val_y2_output_loss: 0.4875 - val_y1_output_root_mean_squared_error: 0.5358 - val_y2_output_root_mean_squared_error: 0.7042
# Epoch 485/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.3860 - y1_output_loss: 0.1050 - y2_output_loss: 0.2784 - y1_output_root_mean_squared_error: 0.3251 - y2_output_root_mean_squared_error: 0.5295 - val_loss: 0.7915 - val_y1_output_loss: 0.2636 - val_y2_output_loss: 0.5127 - val_y1_output_root_mean_squared_error: 0.5214 - val_y2_output_root_mean_squared_error: 0.7209
# Epoch 486/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.5266 - y1_output_loss: 0.1420 - y2_output_loss: 0.3801 - y1_output_root_mean_squared_error: 0.3785 - y2_output_root_mean_squared_error: 0.6192 - val_loss: 0.9041 - val_y1_output_loss: 0.2618 - val_y2_output_loss: 0.6155 - val_y1_output_root_mean_squared_error: 0.5211 - val_y2_output_root_mean_squared_error: 0.7953
# Epoch 487/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.4510 - y1_output_loss: 0.1292 - y2_output_loss: 0.3217 - y1_output_root_mean_squared_error: 0.3609 - y2_output_root_mean_squared_error: 0.5663 - val_loss: 0.8758 - val_y1_output_loss: 0.3720 - val_y2_output_loss: 0.4839 - val_y1_output_root_mean_squared_error: 0.6198 - val_y2_output_root_mean_squared_error: 0.7012
# Epoch 488/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.3461 - y1_output_loss: 0.1112 - y2_output_loss: 0.2326 - y1_output_root_mean_squared_error: 0.3346 - y2_output_root_mean_squared_error: 0.4839 - val_loss: 0.8507 - val_y1_output_loss: 0.2784 - val_y2_output_loss: 0.5503 - val_y1_output_root_mean_squared_error: 0.5370 - val_y2_output_root_mean_squared_error: 0.7499
# Epoch 489/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.7524 - y1_output_loss: 0.2095 - y2_output_loss: 0.5605 - y1_output_root_mean_squared_error: 0.4511 - y2_output_root_mean_squared_error: 0.7409 - val_loss: 4.0843 - val_y1_output_loss: 0.7136 - val_y2_output_loss: 3.3444 - val_y1_output_root_mean_squared_error: 0.8422 - val_y2_output_root_mean_squared_error: 1.8371
# Epoch 490/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.4254 - y1_output_loss: 0.1249 - y2_output_loss: 0.2973 - y1_output_root_mean_squared_error: 0.3547 - y2_output_root_mean_squared_error: 0.5474 - val_loss: 0.8331 - val_y1_output_loss: 0.2906 - val_y2_output_loss: 0.5240 - val_y1_output_root_mean_squared_error: 0.5489 - val_y2_output_root_mean_squared_error: 0.7293
# Epoch 491/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.2707 - y1_output_loss: 0.0951 - y2_output_loss: 0.1737 - y1_output_root_mean_squared_error: 0.3097 - y2_output_root_mean_squared_error: 0.4181 - val_loss: 0.8631 - val_y1_output_loss: 0.3182 - val_y2_output_loss: 0.5238 - val_y1_output_root_mean_squared_error: 0.5727 - val_y2_output_root_mean_squared_error: 0.7315
# Epoch 492/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.2816 - y1_output_loss: 0.1074 - y2_output_loss: 0.1748 - y1_output_root_mean_squared_error: 0.3264 - y2_output_root_mean_squared_error: 0.4184 - val_loss: 0.8141 - val_y1_output_loss: 0.2731 - val_y2_output_loss: 0.5337 - val_y1_output_root_mean_squared_error: 0.5304 - val_y2_output_root_mean_squared_error: 0.7299
# Epoch 493/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.3468 - y1_output_loss: 0.1037 - y2_output_loss: 0.2439 - y1_output_root_mean_squared_error: 0.3215 - y2_output_root_mean_squared_error: 0.4934 - val_loss: 1.1173 - val_y1_output_loss: 0.2743 - val_y2_output_loss: 0.8057 - val_y1_output_root_mean_squared_error: 0.5327 - val_y2_output_root_mean_squared_error: 0.9130
# Epoch 494/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.4140 - y1_output_loss: 0.1481 - y2_output_loss: 0.2711 - y1_output_root_mean_squared_error: 0.3803 - y2_output_root_mean_squared_error: 0.5190 - val_loss: 2.3840 - val_y1_output_loss: 0.7724 - val_y2_output_loss: 1.5527 - val_y1_output_root_mean_squared_error: 0.8920 - val_y2_output_root_mean_squared_error: 1.2603
# Epoch 495/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.3944 - y1_output_loss: 0.1274 - y2_output_loss: 0.2698 - y1_output_root_mean_squared_error: 0.3562 - y2_output_root_mean_squared_error: 0.5172 - val_loss: 0.7907 - val_y1_output_loss: 0.2514 - val_y2_output_loss: 0.5303 - val_y1_output_root_mean_squared_error: 0.5101 - val_y2_output_root_mean_squared_error: 0.7283
# Epoch 496/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.3373 - y1_output_loss: 0.1025 - y2_output_loss: 0.2347 - y1_output_root_mean_squared_error: 0.3182 - y2_output_root_mean_squared_error: 0.4859 - val_loss: 0.7933 - val_y1_output_loss: 0.2581 - val_y2_output_loss: 0.5154 - val_y1_output_root_mean_squared_error: 0.5176 - val_y2_output_root_mean_squared_error: 0.7249
# Epoch 497/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.3242 - y1_output_loss: 0.1066 - y2_output_loss: 0.2164 - y1_output_root_mean_squared_error: 0.3263 - y2_output_root_mean_squared_error: 0.4666 - val_loss: 1.0662 - val_y1_output_loss: 0.3537 - val_y2_output_loss: 0.6904 - val_y1_output_root_mean_squared_error: 0.6041 - val_y2_output_root_mean_squared_error: 0.8374
# Epoch 498/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.2844 - y1_output_loss: 0.1007 - y2_output_loss: 0.1858 - y1_output_root_mean_squared_error: 0.3147 - y2_output_root_mean_squared_error: 0.4306 - val_loss: 0.9374 - val_y1_output_loss: 0.3599 - val_y2_output_loss: 0.5528 - val_y1_output_root_mean_squared_error: 0.6113 - val_y2_output_root_mean_squared_error: 0.7508
# Epoch 499/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.3561 - y1_output_loss: 0.1151 - y2_output_loss: 0.2425 - y1_output_root_mean_squared_error: 0.3361 - y2_output_root_mean_squared_error: 0.4931 - val_loss: 1.2448 - val_y1_output_loss: 0.4474 - val_y2_output_loss: 0.7572 - val_y1_output_root_mean_squared_error: 0.6805 - val_y2_output_root_mean_squared_error: 0.8842
# Epoch 500/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.3972 - y1_output_loss: 0.1347 - y2_output_loss: 0.2611 - y1_output_root_mean_squared_error: 0.3673 - y2_output_root_mean_squared_error: 0.5122 - val_loss: 0.7861 - val_y1_output_loss: 0.2514 - val_y2_output_loss: 0.5250 - val_y1_output_root_mean_squared_error: 0.5099 - val_y2_output_root_mean_squared_error: 0.7253

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 35us/sample - loss: 0.7861 - y1_output_loss: 0.2607 - y2_output_loss: 0.5192 - y1_output_root_mean_squared_error: 0.5099 - y2_output_root_mean_squared_error: 0.7253
# Loss = 0.7861013845963911, Y1_loss = 0.26070335507392883, Y1_mse = 0.5099462866783142, Y2_loss = 0.5191819667816162, Y2_mse = 0.7252972722053528

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
